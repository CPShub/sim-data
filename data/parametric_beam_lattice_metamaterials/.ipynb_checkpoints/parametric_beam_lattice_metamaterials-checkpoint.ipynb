# %% [markdown]
# # Data on the effective constitutive behavior of parametric beam lattice metamaterials
#
# Created by Mauricio Fernández
#
# Contributors:
# * Mauricio Fernández
# * Oliver Weeger

# %%
import modules.data as md
import modules.plot as mp

# %% [markdown]
# ## Get parameters of simulated unit cells

# %%
# Get parameters and corresponding folders from calibration set
# p = [E, t1, t2, t3]
ps, folders = md.get_ps_folders()
for i in range(5):
    print(f'Parameter {i+1}:', ps[i])

# Extract topology parameters: t = [t1, t2, t3]
ts = ps[:, 1:]
for i in range(5):
    print(f'Cell topology {i+1}:', ts[i])
# Out:
# Parameter 1: [1.    0.825 0.275 0.785]
# Parameter 2: [1.    0.415 0.675 0.055]
# Parameter 3: [1.    0.225 0.815 0.625]
# Parameter 4: [1.    0.085 0.965 0.865]
# Parameter 5: [1.    0.905 0.195 0.025]
# Cell topology 1: [0.825 0.275 0.785]
# Cell topology 2: [0.415 0.675 0.055]
# Cell topology 3: [0.225 0.815 0.625]
# Cell topology 4: [0.085 0.965 0.865]
# Cell topology 5: [0.905 0.195 0.025]

# %% [markdown]
# ## Simulated scenarios

# %%
# List of scenarios
print(md.scenarios_dict['all'])
# Out:
# ['uniaxial', 'biaxial', 'planar', 'volumetric', 'shear', 'biaxial2', 'biaxial3', 'uniaxial-shear']

# %% [markdown]
# ## Plot single cases

# %%
# Get (from calibration set) uniaxial tension case and plot
t0 = ts[3]
Fs, ps, Ws, Ps = md.get_case(
    t=t0,
    scenario='uniaxial',
    tc='c'
    )

# Plot
mp.plot_WP(Fs, Ws, Ps, title='uniaxial - compression')

# %%
Fs, ps, Ws, Ps = md.get_case(t=t0, scenario='shear', tc='t')
mp.plot_WP(Fs, Ws, Ps, title='shear - tension', Fc='12')

# %% [markdown]
# ## Load complete dataset

# %%
Fs, ps, Ws, Ps = md.get_all()

print('F:', Fs.shape)
print('p:', ps.shape)
print('W:', Ws.shape)
print('P:', Ps.shape)
# Out:
# F: (107, 16, 151, 3, 3)
# p: (107, 16, 151, 4)
# W: (107, 16, 151, 1)
# P: (107, 16, 151, 3, 3)
